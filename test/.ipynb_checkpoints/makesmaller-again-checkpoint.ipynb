# %%
class myNumber:
    def __init__(self, number):
        self.number = number
        self.nextmyn = None
        
    def add(self, x):
        if self.nextmyn == None:
            self.nextmyn = myNumber(x)
            self.lastmyn = self.nextmyn
        else:
            self.lastmyn.nextmyn = myNumber(x)
            self.lastmyn = self.lastmyn.nextmyn

# %%
x = myNumber(1)

# %%
x

# %%
x.number
# Out:
# 1

# %%
x.nextmyn

# %%
x.add(2)

# %%
x.number
# Out:
# 1

# %%
x.nextmyn.number
# Out:
# 2

# %%
x.add(3)

# %%
x.number
# Out:
# 1

# %%
x.nextmyn.number
# Out:
# 2

# %%
x.nextmyn.nextmyn.number
# Out:
# 3

# %%
class myNumber:
    def __init__(self, number):
        self.number = number
        self.nextmyn = None
        
    def add(self, x):
        if self.nextmyn is not None:
            self.lastmyn.nextmyn = myNumber(x)
            self.lastmyn = self.lastmyn.nextmyn
        else:
            self.nextmyn = myNumber(x)
            self.lastmyn = self.nextmyn
    def get(self, index):
        if index != 0:
            tar = self.nextmyn
            for i in range(index-1):
                tar = tar.nextmyn
            return tar.number
        else:
            return self.number

# %%
x = myNumber(1)
x.add(10)
x.add(100)
x.add(1009)
x.add(10009)
x.add(900009)

# %%
x.get(0)
# Out:
# 1

# %%
x.get(1)
# Out:
# 10

# %%
x.get(2)
# Out:
# 100

# %%
x.get(3)
# Out:
# 1009

# %%
x.get(4)
# Out:
# 10009

# %%
x.get(5)
# Out:
# 900009

# %%
x.get(6)
# Out:
# ------
# AttributeErrorTraceback (most recent call last)
# Cell In[21], line 1
# ----> 1 x.get(6)
#
# Cell In[13], line 18, in myNumber.get(self, index)
#      14         if index != 0:
#      15             tar = self.nextmyn
#      16             for i in range(index-1):
#      17                 tar = tar.nextmyn
# ---> 18             return tar.number
#      19         else:
#      20             return self.number
#
# AttributeError: 'NoneType' object has no attribute 'number'

# %%
class myNum:
    def __init__(self, number):
        self.number = number
        self.nextmyn = None
        
    def add(self, x):
        if self.nextmyn is not None:
            self.lastmyn.nextmyn = myNumber(x)
            self.lastmyn = self.lastmyn.nextmyn
        else:
            self.nextmyn = myNumber(x)
            self.lastmyn = self.nextmyn

    def get(self, index):
        if index != 0:
            tar = self.nextmyn
            for i in range(index-1):
                tar = tar.nextmyn
            return tar.number
        else:
            return self.number

    def printt(self):
        print()
        go=True
        tar = self.nextmyn
        print(f"[{self.number}",end=",")
        count = 1
        while go:
            count += 1
            print(tar.number,end=",")
            tar = tar.nextmyn
            
            if tar.nextmyn.nextmyn is None:
                print(tar.number,end=",")
                print(tar.nextmyn.number,end="]")
                count+= 2
                go = False
        print()
        print(f"\nlength: {count}")

# %%
xs = myNum("we can")
xs.add("store more than")
xs.add("numbers")
xs.add(9)
xs.add(3.3)

xs.printt()
# Out:
# [we can,store more than,numbers,9,3.3]
#
# length: 5

# %%
xs.add(["see", ":)"])
xs.add(9999)

xs.printt()
# Out:
# [we can,store more than,numbers,9,3.3,['see', ':)'],9999]
#
# length: 7

# %%
pullout = xs.get(5)
pullout
# Out:
# ['see', ':)']

# %%
pullout[1]
# Out:
# ':)'

# %%
class myNum:
    def __init__(self, number):
        self.number = number
        self.nextmyn = None
        
    def add(self, x):
        if self.nextmyn is not None:
            self.lastmyn.nextmyn = myNumber(x)
            self.lastmyn = self.lastmyn.nextmyn
        else:
            self.nextmyn = myNumber(x)
            self.lastmyn = self.nextmyn

    def get(self, index):
        if index != 0:
            tar = self.nextmyn
            for i in range(index-1):
                tar = tar.nextmyn
            return tar.number
        else:
            return self.number

    def printt(self):
        print()
        go=True
        tar = self.nextmyn
        print(f"[{self.number}",end=",")
        count = 1
        while go:
            count += 1
            print(tar.number,end=",")
            tar = tar.nextmyn
            
            if tar.nextmyn.nextmyn is None:
                print(tar.number,end=",")
                print(tar.nextmyn.number,end="]")
                count+= 2
                go = False
        print()
        print(f"\nlength: {count}")

        
    def printdown(self):
        print()
        go=True
        tar = self.nextmyn
        print(f"[{self.number}",end="\n")
        count = 1
        while go:
            count += 1
            print(f" {tar.number}",end="\n")
            tar = tar.nextmyn
            
            if tar.nextmyn.nextmyn is None:
                print(f" {tar.number}",end="\n")
                print(f" {tar.nextmyn.number}",end="]")
                count+= 2
                go = False
        print()
        print(f"\nlength: {count}")

# %%
xs = myNum("a")
xs.add("A")
xs.add("b")
xs.add("B")
xs.add("c")
xs.add("C")

xs.printdown()
# Out:
# [a
#  A
#  b
#  B
#  c
#  C]
#
# length: 6

# %%
class myList:
    def __init__(self, listitem):
        self.li = listitem
        self.ni = None
        
    def add(self, x):
        if self.ni is not None:
            self.las.ni = myList(x)
            self.las = self.las.ni
        else:
            self.ni = myList(x)
            self.las = self.ni

    def get(self, index):
        if index != 0:
            tar = self.ni
            for i in range(index-1):
                tar = tar.ni
            return tar.li
        else:
            return self.li

    def printt(self):
        print()
        go=True
        tar = self.ni
        print(f"[{self.li}",end=",")
        count = 1
        while go:
            count += 1
            print(tar.li,end=",")
            tar = tar.ni
            
            if tar.ni.ni is None:
                print(tar.li,end=",")
                print(tar.ni.li,end="]")
                count+= 2
                go = False
        print()
        print(f"\nlength: {count}")

        
    def printdown(self):
        print()
        go=True
        tar = self.ni
        print(f"[{self.li}",end="\n")
        count = 1
        while go:
            count += 1
            print(f" {tar.li}",end="\n")
            tar = tar.ni
            
            if tar.ni.ni is None:
                print(f" {tar.li}",end="\n")
                print(f" {tar.ni.li}",end="]")
                count+= 2
                go = False
        print()
        print(f"\nlength: {count}")

# %%
xs = myList("a")
xs.add("A")
xs.add("b")
xs.add("B")
xs.add("c")
xs.add("C")
xs.add(1)
xs.add(2)
xs.add(3)
xs.add(4)

print("xs:")
xs.printdown()
# Out:
# xs:
#
# [a
#  A
#  b
#  B
#  c
#  C
#  1
#  2
#  3
#  4]
#
# length: 10
