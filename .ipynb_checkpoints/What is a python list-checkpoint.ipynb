# %% [markdown]
# we want to store 4 different numbers in
# one variable how

# %%
class myNumber:
    def __init__(self,number2store):
        self.number2store = number2store

# %%
mynum = myNumber(3)

# %%
type(mynum)
# Out:
# __main__.myNumber

# %%
type(print)
# Out:
# builtin_function_or_method

# %%
type(3)
# Out:
# int

# %%
type("hi")
# Out:
# str

# %%
type(mynum)
# Out:
# __main__.myNumber

# %%
dir(mynum)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'number2store']

# %%
mynum.number2store
# Out:
# 3

# %%
class mynNumber:
    def __init__(self,number2store):
        self.number2store = number2store
        self.mynextnumber = False

# %%
mynnum = mynNumber(3)

# %%
mynnum.number2store
# Out:
# 3

# %%
mynnum.mynextnumber
# Out:
# False

# %%
mynnum.mynextnumber = mynNumber(6)

# %%
mynnum.number2store
# Out:
# 3

# %%
type(mynnum.mynextnumber)
# Out:
# __main__.mynNumber

# %% [markdown]
# print each step in the list of mynnumber can
# step to a next mynNumber class (object if
# we use the .mynextnumber member/object/class/self
#                                 shatevee
# variable to hold a new jnstsntionbkfn thr class
# thag the variabke resides in
# kinda l*enrecursion
#
#                     okay

# %% [markdown]
# lets count to 3

# %% [markdown]
# change nsme kf shit

# %%
class myNumbers:
    def __init__(self, numprovided):
        self.number_value = numprovided
        self.next_number = False

# %%
thenumberone = myNumbers(1)
thenumberone.number_value
# Out:
# 1

# %%
thenumbertwo = myNumbers(2)
thenumbertwo.number_value
# Out:
# 2

# %%
thenumberthree = myNumbers(3)
thenumberthree.number_value
# Out:
# 3

# %%
all([thenumberone.next_number,
 thenumbertwo.next_number,
 thenumberthree.next_number]) == False
# Out:
# True

# %% [markdown]
# hook them tkgrther

# %%
one = thenumberone
two = thenumbertwo
three = thenumberthree
# rename for lessncharscters below

# %%
one.number_value
# Out:
# 1

# %% [markdown]
# right

# %% [markdown]
# okay

# %%
all([one.next_number, two.next_number, \
    three.next_number]) == False
# Out:
# True

# %%
two.next_number = three

# %%
one.next_number = two

# %% [markdown]
# or this way

# %%
one.next_number = two

# %%
one.next_number.next_number = three

# %% [markdown]
# right?

# %% [markdown]
# okay

# %%
one.number_value
# Out:
# 1

# %%
one.next_number.number_value
# Out:
# 2

# %%
one.next_number.next_number.number_value
# Out:
# 3

# %%
one.next_number.next_number.next_number
# Out:
# False

# %%
x= one # sincebwe alresdy hookednthemntogrther

# %%
go = True
while go:
    if x.next_number == False:
        go = False
    print(x.number_value)
    x = x.next_number
# Out:
# 1
# 2
# 3

# %% [markdown]
# okay lets rewritenit snd say we eantntonstorr (
# assume python listsndont exist)
#
# we want tonstoren thisnas a list
#
# [9, "is", "my", "<", '3', "num"]
#
# okay

# %%
class fuckyoupythnlists:
    def __init__(self, whattoaddtolist):
        self.variabletostore = whattoaddtolist
        self.nextlistitem = False

# %%
mylist = fuckyoupythnlists(9)

# %%
mylist\
    .nextlistitem = fuckyoupythnlists("is")

# %%
mylist.nextlistitem \
    .nextlistitem = fuckyoupythnlists("my")

# %%
mylist.nextlistitem \
    .nextlistitem \
    .nextlistitem = fuckyoupythnlists("<")

# %%
mylist.nextlistitem \
    .nextlistitem \
    .nextlistitem \
    .nextlistitem = fuckyoupythnlists('3')

# %%
mylist.nextlistitem \
    .nextlistitem \
    .nextlistitem \
    .nextlistitem \
    .nextlistitem= fuckyoupythnlists('num')

# %%
x = mylist
go = True
while go:
    if x.nextlistitem == False:
        go = False
    print(x.variabletostore,end="")
    x = x.nextlistitem
# Out:
# 9ismy<3num
