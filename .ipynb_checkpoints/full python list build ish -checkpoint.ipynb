# %%
class listitem:
    def __init__(self, item):
        self.item = item
        self.nextlistitem = None

class list:
    def __init__(self, *args):
        self.args = args
        self.firstitem = self.lastitem = None
        self.number_of_items = 0
        
        for arg_i in args:
            item = listitem(arg_i)
            if self.number_of_items == 0:
                self.firstitem = self.lastitem = item
            else:
                self.lastitem.nextlistitem = item
                self.lastitem = item
            self.number_of_items += 1
    def append(self, singappend):
        nextitem = listitem(singappend)
        self.lastitem.nextlistitem = nextitem
        self.lastitem = nextitem
        self.number_of_items += 1
    def pplist(self):
        skipper = self.firstitem
        print("[",end="")
        endchar=","
        for i in range(self.number_of_items):
            if i == self.number_of_items - 1:
                endchar="]"
            print(skipper.item, end=endchar)
            skipper = skipper.nextlistitem
        print()
        
                
    
    def heygettheshit(self):
        return self.args

# %%
x = list(1,2,3,4,5,6,"Hello")
x.pplist()
# Out:
# [1,2,3,4,5,6,Hello]

# %%
x.append("sjngulatappend")

# %%
x.pplist()
# Out:
# [1,2,3,4,5,6,Hello,sjngulatappend]

# %%
class DynamicProfile:
    def __init__(self, *args, **kwargs):
        print("Positional arguments:", args)
        print("Keyword arguments:", kwargs)

# Example usage
p = DynamicProfile("Tallahassee", "FL", age=30, active=True)
# Out:
# Positional arguments: ('Tallahassee', 'FL')
# Keyword arguments: {'age': 30, 'active': True}
